# %%
import itertools
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def generate_dna_sequences(n: int): 
    return np.array(["".join(x) for x in list(itertools.product('ACTG', repeat=n))])

def one_hot_encode_dna_sequences(lst):
    mp = {
        "A" : [1, 0, 0, 0], 
        "C" : [0, 1, 0, 0], 
        "T" : [0, 0, 1, 0], 
        "G" : [0, 0, 0, 1]
    }
    return np.array([[mp[i] for i in string] for string in lst])

def one_hot_encode_flat_dna_sequences(lst):
    mp = {
        "A" : [1, 0, 0, 0], 
        "C" : [0, 1, 0, 0], 
        "T" : [0, 0, 1, 0], 
        "G" : [0, 0, 0, 1]
    }
    return np.array([np.array([mp[i] for i in string]).flatten() for string in lst])

def generate_output(lst, dna_seq_length, add_bias=False, add_nonlinearity=False, layers = []):
    input_size = dna_seq_length;
    state = lst
    for hidden_size in layers:
        W = np.random.randn(input_size, hidden_size)
        if add_bias:
            b = np.random.randn(1)
        else: 
            b = np.zeros(1)
        state = np.matmul(state, W) + b 
        if add_nonlinearity: 
            state = sigmoid(state)
        input_size = hidden_size 
    W = np.random.randn(input_size, 1)
    if add_bias:
        b = np.random.randn(1)
    else: 
        b = np.zeros(1)
    output = np.matmul(state, W) + b
    if add_nonlinearity:
        return sigmoid(output)
    else: 
        return output 

def sigmoid(x):
    return 1. / (1. + np.exp(-x))

def normalize(x): 
    return (x - np.mean(x)) / np.std(x)

def get_sorted_outputs(inputs, outputs): 
    return sorted(list(zip(inputs, outputs)), key = lambda x: x[1], reverse=True)

# %%
length = 4
dna_sequences = generate_dna_sequences(length)
inputs = one_hot_encode_flat_dna_sequences(dna_sequences)
outputs = normalize(generate_output(inputs, 4 * n, add_nonlinearity=True, layers=[20, 50]))
sorted_outputs = get_sorted_outputs(dna_sequences, outputs)

# %%
sorted_outputs
# Out:
# [('GGTG', array([1.54705659])),
#  ('GGCG', array([1.49607216])),
#  ('CGCA', array([1.48927861])),
#  ('CGGA', array([1.46647632])),
#  ('GGGG', array([1.44153516])),
#  ('GGCA', array([1.42173691])),
#  ('GGTA', array([1.41588334])),
#  ('ACGA', array([1.39163767])),
#  ('GTTA', array([1.37601004])),
#  ('GCTA', array([1.33367195])),
#  ('GCCA', array([1.32974015])),
#  ('GTGA', array([1.3253508])),
#  ('ACCA', array([1.32517114])),
#  ('CCCA', array([1.32492575])),
#  ('GCTG', array([1.31924604])),
#  ('AGCA', array([1.31594767])),
#  ('GGTT', array([1.3144816])),
#  ('ACTA', array([1.30286667])),
#  ('GGGA', array([1.30246502])),
#  ('CGAA', array([1.2962028])),
#  ('ATGA', array([1.29566122])),
#  ('CTGA', array([1.29524149])),
#  ('CGGG', array([1.2649144])),
#  ('ATTA', array([1.26266274])),
#  ('GGAG', array([1.25597044])),
#  ('GCGA', array([1.24411546])),
#  ('AGGA', array([1.23998423])),
#  ('CCGA', array([1.21330089])),
#  ('AGGG', array([1.21198154])),
#  ('ATGG', array([1.20653797])),
#  ('GTCA', array([1.19034783])),
#  ('CTCA', array([1.18719123])),
#  ('CTTA', array([1.18561833])),
#  ('GGGT', array([1.18200879])),
#  ('GGAA', array([1.17731037])),
#  ('ATCA', array([1.17278005])),
#  ('ATTG', array([1.15353728])),
#  ('AGTA', array([1.15230537])),
#  ('AAGA', array([1.12414274])),
#  ('GTAA', array([1.10059774])),
#  ('GTTG', array([1.08455244])),
#  ('CCTA', array([1.07916499])),
#  ('CGTA', array([1.05361628])),
#  ('AGTG', array([1.02692117])),
#  ('GCGG', array([1.02351494])),
#  ('AATA', array([1.01682024])),
#  ('GCCG', array([1.01501248])),
#  ('ATAA', array([1.0100148])),
#  ('GTGG', array([0.99610671])),
#  ('AAGG', array([0.99610641])),
#  ('GCAA', array([0.99126262])),
#  ('CTAA', array([0.98566734])),
#  ('ACGG', array([0.98419568])),
#  ('ACTG', array([0.96059073])),
#  ('AGAA', array([0.95936844])),
#  ('ACAA', array([0.94559478])),
#  ('CGCG', array([0.92406103])),
#  ('CGGT', array([0.92298993])),
#  ('AACA', array([0.91835255])),
#  ('TGGA', array([0.89236565])),
#  ('GGAT', array([0.88777762])),
#  ('AGCG', array([0.88648008])),
#  ('GGCC', array([0.84662834])),
#  ('GAGA', array([0.83673814])),
#  ('GGCT', array([0.82779398])),
#  ('GCGT', array([0.81563793])),
#  ('ATGT', array([0.80850367])),
#  ('GTCG', array([0.79261005])),
#  ('CTGG', array([0.78767953])),
#  ('GCTT', array([0.78435711])),
#  ('AATG', array([0.78417976])),
#  ('ACGT', array([0.77749053])),
#  ('GGTC', array([0.77746663])),
#  ('TGTA', array([0.77394915])),
#  ('GATG', array([0.73745774])),
#  ('GATA', array([0.72935114])),
#  ('AGTT', array([0.72855393])),
#  ('AAAA', array([0.71920118])),
#  ('CGCT', array([0.70375317])),
#  ('AGGT', array([0.69510673])),
#  ('GGAC', array([0.68292256])),
#  ('GAGG', array([0.6786692])),
#  ('CGAT', array([0.6553313])),
#  ('GTGT', array([0.64938475])),
#  ('AAGT', array([0.64746987])),
#  ('ATTT', array([0.6471037])),
#  ('TGGG', array([0.64329613])),
#  ('CCAA', array([0.63970515])),
#  ('GACA', array([0.63954211])),
#  ('GGGC', array([0.62903623])),
#  ('TGCA', array([0.6122376])),
#  ('AATT', array([0.6107064])),
#  ('ACTT', array([0.59308265])),
#  ('CGTG', array([0.59106111])),
#  ('GACG', array([0.58800284])),
#  ('CGGC', array([0.57420092])),
#  ('CGTT', array([0.56187937])),
#  ('CGAG', array([0.53634915])),
#  ('GAAA', array([0.52847973])),
#  ('CCGG', array([0.47170165])),
#  ('CAGA', array([0.45059806])),
#  ('GTAG', array([0.43055222])),
#  ('ATCG', array([0.4218945])),
#  ('TGGT', array([0.4216911])),
#  ('AGAG', array([0.41308792])),
#  ('ATGC', array([0.40115235])),
#  ('GCCT', array([0.39454525])),
#  ('CACA', array([0.32414056])),
#  ('ACCG', array([0.32084234])),
#  ('GCAG', array([0.31281834])),
#  ('AGCT', array([0.31197059])),
#  ('CTGT', array([0.30486125])),
#  ('GTTT', array([0.29831227])),
#  ('AGGC', array([0.28754595])),
#  ('GCCC', array([0.27565928])),
#  ('CTTG', array([0.2727784])),
#  ('CTCG', array([0.25393115])),
#  ('GTCC', array([0.25297929])),
#  ('GCAT', array([0.24827812])),
#  ('GAAG', array([0.2315255])),
#  ('GTAT', array([0.2057012])),
#  ('CATA', array([0.19728059])),
#  ('TGTT', array([0.1913614])),
#  ('AGAT', array([0.18187869])),
#  ('GAGT', array([0.17675275])),
#  ('GATT', array([0.15670712])),
#  ('CTGC', array([0.12794339])),
#  ('TTGA', array([0.11494855])),
#  ('GTCT', array([0.1043169])),
#  ('AACG', array([0.09804186])),
#  ('CCCG', array([0.08628888])),
#  ('AAGC', array([0.07930171])),
#  ('GTGC', array([0.04690783])),
#  ('CGCC', array([0.04436776])),
#  ('ACGC', array([0.03580774])),
#  ('TGCG', array([0.02575392])),
#  ('CAGG', array([0.01588426])),
#  ('CTTT', array([0.00529273])),
#  ('TGTG', array([-0.01695589])),
#  ('ATTC', array([-0.01909664])),
#  ('GAAT', array([-0.03412383])),
#  ('CCGT', array([-0.05146])),
#  ('TTCA', array([-0.07037942])),
#  ('CAAA', array([-0.07205794])),
#  ('ATAG', array([-0.08094484])),
#  ('TTGG', array([-0.09071224])),
#  ('GCGC', array([-0.10846681])),
#  ('CCTT', array([-0.12319076])),
#  ('CGAC', array([-0.13240856])),
#  ('CTCC', array([-0.14407538])),
#  ('ACCT', array([-0.16694247])),
#  ('CCTG', array([-0.19146275])),
#  ('CGTC', array([-0.20376906])),
#  ('GCTC', array([-0.22590769])),
#  ('AGTC', array([-0.23409233])),
#  ('CTCT', array([-0.23813267])),
#  ('TGCT', array([-0.26343468])),
#  ('ATCT', array([-0.27855876])),
#  ('TGAA', array([-0.29179872])),
#  ('AACT', array([-0.3026245])),
#  ('ATAT', array([-0.3433161])),
#  ('AAAG', array([-0.34462238])),
#  ('CCCT', array([-0.34583344])),
#  ('GACT', array([-0.3576968])),
#  ('ACTC', array([-0.37452082])),
#  ('TGCC', array([-0.40484488])),
#  ('TACA', array([-0.40565159])),
#  ('AAAT', array([-0.41192346])),
#  ('TCGG', array([-0.4222706])),
#  ('CCGC', array([-0.42451237])),
#  ('GTTC', array([-0.4441456])),
#  ('TCGA', array([-0.45894012])),
#  ('TTGT', array([-0.45937025])),
#  ('AATC', array([-0.46913441])),
#  ('TCCA', array([-0.48368251])),
#  ('ACAT', array([-0.52676473])),
#  ('GTAC', array([-0.53329621])),
#  ('TGGC', array([-0.53636146])),
#  ('CACG', array([-0.53996088])),
#  ('ACAG', array([-0.54510549])),
#  ('AGCC', array([-0.57581191])),
#  ('CTAT', array([-0.58013272])),
#  ('CAGT', array([-0.59591491])),
#  ('TAGA', array([-0.59803735])),
#  ('GAGC', array([-0.60304383])),
#  ('TTTG', array([-0.61524562])),
#  ('TAGG', array([-0.61657565])),
#  ('GAAC', array([-0.61836])),
#  ('TTTA', array([-0.63349575])),
#  ('CTAG', array([-0.66327971])),
#  ('GACC', array([-0.6641532])),
#  ('GCAC', array([-0.66635379])),
#  ('TTCG', array([-0.69008384])),
#  ('CCCC', array([-0.69284458])),
#  ('TTTT', array([-0.76638357])),
#  ('TATA', array([-0.77572785])),
#  ('TCTA', array([-0.79582228])),
#  ('ATCC', array([-0.8068783])),
#  ('CTTC', array([-0.8267386])),
#  ('TACG', array([-0.89159121])),
#  ('AGAC', array([-0.90761512])),
#  ('TCGT', array([-0.91073427])),
#  ('CCAT', array([-0.91479032])),
#  ('CCAG', array([-0.92045526])),
#  ('TGAT', array([-0.9246285])),
#  ('CATT', array([-0.92691825])),
#  ('CACT', array([-0.93428371])),
#  ('TTAA', array([-0.94271337])),
#  ('TCTG', array([-0.98635065])),
#  ('TATG', array([-0.98798762])),
#  ('CATG', array([-1.02454682])),
#  ('TGAG', array([-1.03458114])),
#  ('ACCC', array([-1.06821971])),
#  ('AACC', array([-1.07987286])),
#  ('TAGT', array([-1.08214069])),
#  ('CAAT', array([-1.09027141])),
#  ('TCTT', array([-1.10229602])),
#  ('CTAC', array([-1.11235841])),
#  ('TTCT', array([-1.16207219])),
#  ('TGTC', array([-1.16953295])),
#  ('TCAA', array([-1.17225102])),
#  ('CCTC', array([-1.18464211])),
#  ('TTGC', array([-1.18519719])),
#  ('CAGC', array([-1.19447168])),
#  ('TATT', array([-1.20966107])),
#  ('ACAC', array([-1.23597857])),
#  ('TCCG', array([-1.30333425])),
#  ('ATAC', array([-1.30447594])),
#  ('GATC', array([-1.32864597])),
#  ('CAAG', array([-1.33361237])),
#  ('CACC', array([-1.3566068])),
#  ('TTCC', array([-1.40182744])),
#  ('TACT', array([-1.46704158])),
#  ('TACC', array([-1.46974767])),
#  ('AAAC', array([-1.55069748])),
#  ('TCGC', array([-1.60862533])),
#  ('TAGC', array([-1.68882895])),
#  ('TAAA', array([-1.77302586])),
#  ('CAAC', array([-1.78311557])),
#  ('TCCC', array([-1.79066858])),
#  ('TTAT', array([-1.80008801])),
#  ('TTAG', array([-1.81780672])),
#  ('TCCT', array([-1.86257827])),
#  ('CCAC', array([-1.86563242])),
#  ('TGAC', array([-1.90951316])),
#  ('TCAG', array([-1.91669646])),
#  ('TTTC', array([-1.92401618])),
#  ('CATC', array([-1.93263777])),
#  ('TATC', array([-2.03829845])),
#  ('TCAT', array([-2.05773505])),
#  ('TAAT', array([-2.11655558])),
#  ('TCTC', array([-2.1286936])),
#  ('TAAG', array([-2.17019694])),
#  ('TTAC', array([-2.46939645])),
#  ('TCAC', array([-2.59975407])),
#  ('TAAC', array([-2.75937767]))]

# %%
def reshape_square(outputs): 
    return outputs.reshape(int(np.sqrt(len(outputs))), int(np.sqrt(len(outputs))))

# %%
def visualize(outputs, dna_sequences):
    plt.figure(figsize=(20,20))
    plt.title('DNA Sequence HeatMap', size=20)
    data, labels = reshape_square(outputs), reshape_square(dna_sequences)
    sns.heatmap(data, annot=labels, fmt='', xticklabels=False, yticklabels=False)
    plt.show()

# %%
visualize(outputs, dna_sequences )

# %%
type(np.array([['a', 'b', 'c']])[0][0])
# Out:
# numpy.str_
